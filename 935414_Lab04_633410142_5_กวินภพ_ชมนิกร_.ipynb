# %% [markdown]
# <a href="https://colab.research.google.com/github/Kawin101/935414_SPD2023/blob/main/935414_Lab04_633410142_5_%E0%B8%81%E0%B8%A7%E0%B8%B4%E0%B8%99%E0%B8%A0%E0%B8%9E_%E0%B8%8A%E0%B8%A1%E0%B8%99%E0%B8%B4%E0%B8%81%E0%B8%A3_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# การสร้างตัวเลขสุ่ม การวิเคราะห์ทางสถิติ การหาค่าเหมาะสมที่สุด

# %% [markdown]
# 1. สร้างตัวเลขสุ่มและแสดงแผนภาพการกระจายแบบต่างๆ

# %% [markdown]
# 1.1	การกระจายตัวแบบเอกรูป (uniform distribution)

# %%
# การกระจายตัวแบบเอกรูป (uniform distribution)
# สร้างเลขสุ่มและเขียนภาพการกระจายตัวของค่าสุ่ม X ในช่วง 0 ถึง 1
import numpy as np
import matplotlib.pyplot as plt

start = 0.0
end = 1.0
value = 100000

X = np.random.uniform(start, end, value)
Y = np.random.uniform(start, end, value)

plt.plot(X,Y, '+')
plt.show()

# %% [markdown]
# 1.2	การกระจายตัวแบบปกติ (normal distribution)

# %%
# การกระจายตัวแบบปกติ (normal distribution)
# สร้างเลขสุ่มและเขียนภาพการกระจายของค่าสุ่ม X ที่มีค่าเฉลี่ย 0.0 และส่วนเบี่ยงเบนมาตรฐาน 0.5
import numpy as np
import matplotlib.pyplot as plt

value = 100000 # ตัวแปร
average = 0.0 # ค่าเฉลี่ย
sd = 0.5 # Standard Deviation: S.D.
N = 0 # Number
X0 = np.random.normal(average,sd,value)
Y0 = np.random.normal(average,sd,value)

X1 = np.random.normal(average+10,sd,value) #10 0.5
Y1 = np.random.normal(average+10,sd,value)

X2 = np.random.normal(average+5,sd+0.5,value) #5 1.0
Y2 = np.random.normal(average+5,sd+0.5,value)

plt.plot(X0,Y0, 'r+')
plt.plot(X1,Y1, 'bo')
plt.plot(X2,Y2, 'g*')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# สร้างค่าสุ่มที่มีการกระจายตัวแบบปกติ
mean = 0.0
std_dev = 0.5
num_samples = 100000  # จำนวนตัวอย่าง

# สร้างค่าสุ่มที่มีการกระจายตัวแบบปกติ
random_samples = np.random.normal(mean, std_dev, num_samples)

# พล็อตกราฟการกระจาย
plt.hist(random_samples, bins=30, density=True, alpha=0.6, color='b')
plt.title('การกระจายตัวแบบปกติ (Normal Distribution)')
plt.xlabel('ค่า')
plt.ylabel('ความถี่')
plt.grid(True)
plt.show()

# %% [markdown]
# 1.3	การกระจายตัวแบบทวินาม (binomial distribution)
# <p> โยนลูกเต๋า 1 ลูกจำนวน 100 ครั้งหาความน่าจะเป็นที่จะเกิดแต้มที่มากกว่า 4 เป็นจำนวนครั้งต่างๆ

# %%
#การกระจายตัวแบบทวินาม (binomial distribution)
import numpy as np
import matplotlib.pyplot as plt

# import seaborn as sns
# ลูกเต๋ามีแต้มมากกว่า 4 คือ 5 กับ 6 รวมจำนวน 2 แบบ จาก 6 แบบ คิดเป็นความน่าจะเป็นได้ 2/6

sample = np.random.binomial(n = 365, p = 0.01, size = 10)
sample = np.round(sample,0)
print(sample)

tt = np.array(range(min(sample),max(sample)+1))
print(tt)

plt.hist(sample, bins=tt, edgecolor = "black")
plt.show()

# ค่าเฉลี่ยการเกิดเหตุการณ์
ave = np.average(sample)
cost = ave*1500
print('จำนวนความบกพร่องที่พบเฉลี่ย', ave, 'เงินสำรองสำหรับซ่อมบำรุง', cost)
# Out:
# [6 6 3 5 5 2 2 5 6 1]
# [1 2 3 4 5 6]
# จำนวนความบกพร่องที่พบเฉลี่ย 4.1 เงินสำรองสำหรับซ่อมบำรุง 6149.999999999999

# %% [markdown]
# 1.4	การกระจายตัวแบบเอ็กซ์โปเนนเซียล (exponential)
# <p> ที่เครื่อง ATM แห่งหนึ่งมีผู้มาใช้งานในอัตรา 20 คน ต่อหนึ่งชั่วโมง หากลูกค้าคนหนึ่งพึ่งมาถึงความน่าจะเป็นที่ลูกค้าคนต่อไปจะมาถึง ณ นาทีต่างๆ ถัดไป ตั้งแต่ 1 ถึง 60 เป็นเท่าไร

# %%
#การกระจายตัวแบบเอ็กซ์โปเนนเซียล (exponential)
import numpy as np
import matplotlib.pyplot as plt

#คำนวนค่า beta = 1/lamda, โดยที่ lamda = 20/60 (หนึ่งชั่วดมง = 60 นาที)
time_interval = np.random.exponential(scale=3.0, size=10000)
#print(time_interval)

tt = np.linspace(min(time_interval),max(time_interval),50)

#โอกาสที่ลูกค้าคนถัดไปจะมาถึงในช่วงเวลา 4.0-5.0 นาที

sum4to5 = 0
for t in time_interval:
  if t >= 4.0 and t<5.0:
    sum4to5 += 1

Pt = sum4to5/len(time_interval)
print(f"ความน่าจะเป็นที่ลูกค้าคนต่อไปจะมาถึง ณ น่าทีต่างๆ คือ {Pt}")
plt.hist(time_interval, bins=tt, edgecolor = "black")
plt.show()
# Out:
# ความน่าจะเป็นที่ลูกค้าคนต่อไปจะมาถึง ณ น่าทีต่างๆ คือ 0.0753

# %% [markdown]
# 2. การหาค่าทางสถิติของข้อมูลการซื้อขายหุ้น stock_data.csv

# %%
# !pip install pandas_ta

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install pandas_ta
import numpy as np
import pandas as pd
import pandas_ta as ta
import matplotlib.pyplot as plt

# read data csv
# df = pd.read_csv('stock_data.csv')
df = pd.read_csv('/content/drive/MyDrive/4-1Y2023_First/935414_Math/stock_data.csv')
print(df.head())
print(df.tail())

c_open = df['Open']
c_close = df['Close']

co_min = c_open.min()
co_mean = c_open.mean()

co_max = c_open.max()

txt_min = str(round(co_min,2))
txt_mean = str(round(co_mean,2))
txt_max = str(round(co_max,2))
print(co_min, co_mean, co_max)

days = np.arange(len(c_open))
df['SMA 05'] = ta.sma(c_open,5)
sma05 = df['SMA 05']
df['SMA 10'] = ta.sma(c_open,10)
sma10 = df['SMA 10']
df['SMA 20'] = ta.sma(c_open,20)
sma20 = df['SMA 20']
plt.plot(days, c_open, 'r-', label='Open')

#plt.plot(days, c_close, 'b-', label='Close')
plt.plot(days, sma05, 'b-', label='sma05')
plt.plot(days, sma10, 'g-', label='sma10')
plt.plot(days, sma20, 'y-', label='sma20')
plt.xlabel('days')
plt.ylabel('Prices (Baht)')
plt.legend()
plt.title("min = "+txt_min+", mean = "+txt_mean+", max = "+txt_max)
plt.show()
# Out:
#          Date  Open  High   Low  Close  Adj Close   Volume
# 0  2021-12-20  6.65  6.70  6.55   6.60   6.375255  1062400
# 1  2021-12-21  6.65  6.65  6.50   6.55   6.326957   919100
# 2  2021-12-22  6.60  6.60  6.50   6.55   6.326957   646100
# 3  2021-12-23  6.60  6.65  6.50   6.50   6.278660  1315500
# 4  2021-12-24  6.55  6.55  6.40   6.40   6.182065  2751100
#            Date  Open  High   Low  Close  Adj Close  Volume
# 235  2022-12-09  4.46  4.50  4.46   4.46       4.46   95200
# 236  2022-12-13  4.46  4.46  4.38   4.38       4.38  665000
# 237  2022-12-14  4.38  4.40  4.36   4.38       4.38  230000
# 238  2022-12-15  4.38  4.40  4.36   4.36       4.36  152100
# 239  2022-12-16  4.36  4.42  4.36   4.38       4.38   87800
# 4.360000133514404 5.429291665554047 6.949999809265137

# %%
plt.hist(c_open,label='Open', edgecolor="black", bins=np.arange(4.0,9.5,0.25), color='red')
plt.show()

# %% [markdown]
# **3. การหาค่าเหมาะสมที่สุดและการประยุกต์**

# %% [markdown]
# 3.1 กำหนดตารางข้อมูล x-y จงหาสมการเส้นแนวโน้มข้อมูล y = ax + b โดยใช้การการสุ่ม
# <p> x =	[1,	3,	5,	7,	10,	12,	13,	16,	18,	20]
# <p>y	= [4,	5,	6,	5,	8,	7,	6,	9,	12,	11]

# %%
# Optimization (การหาค่าเหมาะสม)
import numpy as np
import matplotlib.pyplot as plt

xi = [1, 3, 5, 7, 10, 12, 13, 16, 18, 20]
yi = [4, 5, 6, 5, 8, 7, 6, 9, 12, 11]
xi = np.array(xi)
yi = np.array(yi)

# ต้องการหาค่า a, b ที่ทำให้ได้ สมการเส้นตรง ym = axi+b ที่ดีที่สุด (ym ใกล้ yi ที่สุด)
# สุ่มหาค่า a,b

err = np.sum(yi)
a_best = 0.4
b_best = 3.0
print('it == -1', a_best, b_best, err)

for it in range(1000000):
 a = np.random.uniform(0.3, 0.6)
 b = np.random.uniform(2.0, 5.0)
 ym = a*xi + b
 err_it = np.sum((yi-ym)**2)
 if err_it < err:
    a_best = a
    b_best = b
    err = err_it
    print(it, a_best, b_best, err)
plt.plot(xi,yi,'r*')
plt.plot(xi,ym,'bo')
plt.show()
# Out:
# it == -1 0.4 3.0 73
# 1 0.3286665181666796 3.727126798817341 13.004695225147465
# 5 0.33257131980766774 3.75012814210305 12.767173807954935
# 23 0.3645207607495811 3.449933346802807 12.16564643664858
# 535 0.36957257402614757 3.465504574491033 12.161092981466318
# 703 0.373992733419489 3.354366425063198 12.141054431468138
# 12839 0.3700895942917286 3.4056037879380114 12.139600414904548
# 13229 0.37251540746686884 3.394088739627721 12.137018309407196
# 63080 0.3724092724501194 3.3942790506833878 12.136927916287402
# 184809 0.37301668522628134 3.380522958644839 12.136895398026823
# 249841 0.3723545918654152 3.3906821419091644 12.136724822868894

# %%
# Optimization (การหาค่าเหมาะสม)
import numpy as np
import matplotlib.pyplot as plt

xi = [1, 3, 5, 7, 10, 12, 13, 16, 18, 20]
yi = [4, 5, 6, 5, 8, 7, 6, 9, 12, 11]
xi = np.array(xi)
yi = np.array(yi)

# ต้องการหาค่า a, b ที่ทำให้ได้ สมการเส้นตรง ym = axi+b ที่ดีที่สุด (ym ใกล้ yi ที่สุด)
# สุ่มหาค่า a,b

err = np.sum(yi)
a_best = 0.4
b_best = 3.0
a_old = a_best
b_old = b_best
print('it == -1', a_best, b_best, err)

for it in range(1000000):
 a_new = a_old + np.random.uniform(-0.02, 0.02)
 b_new = b_old + np.random.uniform(-0.02, 0.02)
 ym = a_new*xi + b_new
 err_it = np.sum((yi-ym)**2)

 if err_it < err:
    a_best = a_new
    b_best = b_new
    a_old = a_new
    b_old = b_new
    err = err_it
    print(f"No. {it} = ", " | ", a_best," | ", b_best, " | " ,err)

plt.plot(xi,yi,'r*')
plt.plot(xi,ym,'bo')
plt.show()
# Out:
# it == -1 0.4 3.0 73
# No. 0 =   |  0.4116250246974741  |  3.0008280259389766  |  12.715325768374006
# No. 1 =   |  0.4047622672890964  |  3.0181566039835586  |  12.536733657293455
# No. 2 =   |  0.394296010301323  |  3.036911424377651  |  12.465924310151994
# No. 8 =   |  0.39607387139516925  |  3.041502718262528  |  12.444338514744038
# No. 9 =   |  0.39537818097457617  |  3.0585932280504644  |  12.413674911848675
# No. 18 =   |  0.3953474080906188  |  3.076070852144732  |  12.385234530525524
# No. 22 =   |  0.395453190125885  |  3.0770257038797  |  12.384085178276402
# No. 43 =   |  0.3934515347051818  |  3.087146412590355  |  12.367767030372232
# No. 53 =   |  0.3919141775324475  |  3.0982367892051945  |  12.353024153668715
# No. 66 =   |  0.3907987186456001  |  3.106978667985154  |  12.342504063306963
# No. 84 =   |  0.39234326003688813  |  3.118115883194415  |  12.323014311522698
# No. 88 =   |  0.3896763436745627  |  3.1241494163743937  |  12.318224993685634
# No. 108 =   |  0.39197209678589146  |  3.137239874014673  |  12.300900632785911
# No. 114 =   |  0.3897504119254648  |  3.145037587095376  |  12.28736765816804
# No. 122 =   |  0.38998802316502484  |  3.1629762484935267  |  12.269058847890625
# No. 134 =   |  0.38760738049496934  |  3.17513326007106  |  12.252464801872648
# No. 154 =   |  0.38907873757357064  |  3.1808191954379024  |  12.251151070710813
# No. 173 =   |  0.3840965353499828  |  3.198403599933179  |  12.234143214174077
# No. 178 =   |  0.3852860490696892  |  3.208433782380342  |  12.219189718164733
# No. 185 =   |  0.38488334467784563  |  3.2087165366438875  |  12.21918346421286
# No. 191 =   |  0.38513926762192163  |  3.2157540598660046  |  12.212801713426416
# No. 216 =   |  0.3860642612880544  |  3.2220305756213445  |  12.211555800348075
# No. 217 =   |  0.3854699751350497  |  3.2270596179039974  |  12.206251913775986
# No. 230 =   |  0.3822842446681995  |  3.2396907311614456  |  12.194051289423912
# No. 233 =   |  0.38298775638548826  |  3.259294984811356  |  12.181672106128458
# No. 238 =   |  0.38243090459736934  |  3.277334217822794  |  12.174184694982287
# No. 239 =   |  0.381030910921238  |  3.284237861194851  |  12.166223040696051
# No. 240 =   |  0.3792177268067762  |  3.283592168249954  |  12.165619421736233
# No. 276 =   |  0.3812057569541617  |  3.291023309141256  |  12.165519770080806
# No. 302 =   |  0.37983392909994235  |  3.2992585989814174  |  12.158435798654713
# No. 320 =   |  0.37875878516643335  |  3.2990988780449637  |  12.157129637698041
# No. 326 =   |  0.3771185361947637  |  3.314548240033316  |  12.151324149908666
# No. 385 =   |  0.37823945660459807  |  3.31668472396547  |  12.15045914544157
# No. 424 =   |  0.37625857694020254  |  3.3252973920473017  |  12.147769571311505
# No. 452 =   |  0.3765698611854435  |  3.3256761689793186  |  12.14706620493626
# No. 459 =   |  0.3768897812824957  |  3.335708795865069  |  12.144426098369344
# No. 519 =   |  0.37652668231323855  |  3.3547935489995107  |  12.143490740569055
# No. 526 =   |  0.3758695095081435  |  3.343039038971744  |  12.14204328843343
# No. 541 =   |  0.37398132026107217  |  3.353362710679913  |  12.141474745387821
# No. 553 =   |  0.37483686620806134  |  3.3628358428838223  |  12.138785553567201
# No. 562 =   |  0.3732120665031854  |  3.36984899772502  |  12.13821243837817
# No. 593 =   |  0.37368030179023315  |  3.375183233733456  |  12.137254069627026
# No. 643 =   |  0.37237069142743945  |  3.391539030898698  |  12.13674204956934
# No. 1125 =   |  0.37241714713278307  |  3.3885274172514266  |  12.13672992504927
# No. 2166 =   |  0.37265380983359747  |  3.3875004443731536  |  12.136726204764859
# No. 4617 =   |  0.37251654890758457  |  3.3895247485631708  |  12.13672476568712
# No. 5380 =   |  0.3724174480273702  |  3.3895564669276115  |  12.136718007168843
# No. 7633 =   |  0.37248902608334844  |  3.3889023987912457  |  12.136715656483137
# No. 442850 =   |  0.3724953002857442  |  3.388825913933919  |  12.136715628580442

# %%
# Optimization (การหาค่าเหมาะสม)
import numpy as np
import matplotlib.pyplot as plt

xi = [1, 3, 5, 7, 10, 12, 13, 16, 18, 20]
yi = [4, 5, 6, 5, 8, 7, 6, 9, 12, 11]
xi = np.array(xi)
yi = np.array(yi)

# ต้องการหาค่า a, b ที่ทำให้ได้ สมการเส้นตรง ym = axi+b ที่ดีที่สุด (ym ใกล้ yi ที่สุด)
# สุ่มหาค่า a,b
err = np.sum(yi)
a_best = 0.4
b_best = 3.0
a_old = a_best
b_old = b_best

print('it == -1', a_best, b_best, err)

for it in range(1000000):
 a_new = np.random.normal(a_old, 0.01)
 b_new = np.random.normal(b_old, 0.01)
 ym = a_new*xi + b_new
 err_it = np.sum((yi-ym)**2)

 if err_it < err:
    a_best = a_new
    b_best = b_new
    a_old = a_new
    b_old = b_new
    err = err_it
    print(f"No. = {it}", " | ", a_best, " | ", b_best, " | ", err)

plt.plot(xi,yi,'r*')
plt.plot(xi,ym,'bo')
plt.show()
# Out:
# it == -1 0.4 3.0 73
# No. = 0  |  0.39351021982024986  |  3.0103672253689906  |  12.551014415567751
# No. = 1  |  0.39450816437889563  |  3.018613851077271  |  12.511513404219412
# No. = 3  |  0.40290676183917  |  3.0197892514970692  |  12.507734255148113
# No. = 6  |  0.39344952731508254  |  3.0336703903334348  |  12.483675534772184
# No. = 7  |  0.39651583450854777  |  3.0327409719923333  |  12.460605599426549
# No. = 11  |  0.40021326268579854  |  3.041549954513701  |  12.45600677002436
# No. = 12  |  0.3915061802824976  |  3.0598012251243496  |  12.439447495334823
# No. = 23  |  0.3905474419089446  |  3.0718851466078703  |  12.420961995012577
# No. = 26  |  0.39612421778318013  |  3.072638697357159  |  12.392102082570306
# No. = 33  |  0.3929170809965873  |  3.0806341654665386  |  12.380744972218958
# No. = 35  |  0.3958505065988485  |  3.0831739503730855  |  12.377445130027688
# No. = 40  |  0.39656644554660914  |  3.0925807167402266  |  12.372581674111686
# No. = 46  |  0.3923986686621709  |  3.0961501834995198  |  12.35504758046641
# No. = 47  |  0.3942712939423012  |  3.115620160528431  |  12.334109348592113
# No. = 52  |  0.3896792184188599  |  3.1265337246612166  |  12.314251914174502
# No. = 55  |  0.39095614182667326  |  3.135660652024167  |  12.299492122473337
# No. = 60  |  0.3890705311055288  |  3.140820064025939  |  12.294258486631508
# No. = 63  |  0.387667960539598  |  3.14884644474779  |  12.287941693435942
# No. = 69  |  0.38843966239208294  |  3.1503500401465394  |  12.282363339629121
# No. = 82  |  0.39054095964906477  |  3.1555788259838917  |  12.27778440996461
# No. = 87  |  0.3914647319126017  |  3.1705803367720837  |  12.27508131017319
# No. = 94  |  0.38496731542792684  |  3.182053692548455  |  12.252397285272108
# No. = 95  |  0.38691279493809  |  3.2061050435341416  |  12.224349582126369
# No. = 118  |  0.3853957092607291  |  3.2061297432989737  |  12.221319813093167
# No. = 140  |  0.3868125046399592  |  3.2130345760146217  |  12.219935850548257
# No. = 151  |  0.385312748988033  |  3.2166278788994243  |  12.212356795277707
# No. = 181  |  0.38214976268190515  |  3.2346412420334323  |  12.199476292064611
# No. = 185  |  0.3814225734379482  |  3.2463680985618755  |  12.1902646577715
# No. = 209  |  0.38344888707420977  |  3.255738404496976  |  12.184894760766369
# No. = 213  |  0.3802350020898202  |  3.258551612061478  |  12.18313264621173
# No. = 219  |  0.38227957352712627  |  3.2542324801919174  |  12.182690036616673
# No. = 230  |  0.38194404112625147  |  3.255235556236483  |  12.18194146468609
# No. = 237  |  0.37923245414283135  |  3.2649818075170587  |  12.181879149577394
# No. = 252  |  0.37803748141747756  |  3.2830157948175125  |  12.170861724480448
# No. = 259  |  0.379698574304954  |  3.2970879846933365  |  12.158724708209276
# No. = 271  |  0.37972016764483474  |  3.297339504747968  |  12.158689873146177
# No. = 282  |  0.3779989327794343  |  3.307318179522335  |  12.153667196292867
# No. = 287  |  0.3762601828253443  |  3.315519432354424  |  12.15340978395405
# No. = 292  |  0.37669150207482366  |  3.3159241428794797  |  12.151608669455147
# No. = 335  |  0.3783116493087674  |  3.3182114547395427  |  12.15028457773429
# No. = 407  |  0.37580231781054313  |  3.333424314345178  |  12.14507269874696
# No. = 412  |  0.3757371696678282  |  3.342887883142598  |  12.142057608331939
# No. = 429  |  0.3746835118319533  |  3.3656510887916187  |  12.13850689235492
# No. = 465  |  0.3734252873493135  |  3.369878217749691  |  12.1378769407972
# No. = 498  |  0.3732423757647456  |  3.3851752098496486  |  12.137101973158822
# No. = 504  |  0.3727425090015274  |  3.3906089335273473  |  12.136932320594527
# No. = 565  |  0.3722714570363274  |  3.3914509854891772  |  12.136735522206703
# No. = 3578  |  0.37245314197171286  |  3.390048142553673  |  12.136722828643432
# No. = 4336  |  0.3726116796683122  |  3.3874650099660135  |  12.13672070132674
# No. = 4449  |  0.3725010298756571  |  3.388481997837005  |  12.13671628943098
# No. = 7783  |  0.37252169308786687  |  3.3884950450835105  |  12.136715862854857
# No. = 38275  |  0.37247895539064024  |  3.3888785798154135  |  12.136715823601886
# No. = 39521  |  0.3724894097677734  |  3.3889058487802304  |  12.13671566046315
# No. = 606610  |  0.37249792980386826  |  3.388793746620267  |  12.136715626273714

# %% [markdown]
# 3.2 หาค่าเหมาะสมที่สุดสำหรับตัวแบบ SIR โดยใช้ข้อมูล covid_dat.csv

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/4-1Y2023_First/935414_Math/covid_dat.csv')
# print(df.head())
# print(df.tail())
# dataI = df['I']
# dataR = df['R']
# print(dataI)

# Total population, N.
N = 1000
# Initial number of infected and recovered individuals, I0 and R0.
I0, R0 = 1, 0
# Everyone else, S0, is susceptible to infection initially.
S0 = N - I0 - R0

# The SIR model differential equations.
def deriv(y, t, N, beta, gamma):
    S, I, R = y
    dSdt = -beta * S * I / N
    dIdt = beta * S * I / N - gamma * I
    dRdt = gamma * I
    return dSdt, dIdt, dRdt

# Initial conditions vector
y0 = S0, I0, R0
# Integrate the SIR equations over the time grid, t.

# Contact rate, beta, and mean recovery rate, gamma, (in 1/days).
beta, gamma = 1.0, 1.0/7.0
beta_best = beta
gamma_best = gamma
errB = 1000000

for ir in range(1000):
# A grid of time points (in days)
  t = np.linspace(0, 70, 70)
  ret = odeint(deriv, y0, t, args=(N, beta, gamma))
  S, I, R = ret.T

  # errI = df['I'] - I
  # errR = df['R'] - R

  errI = df['I'][:70] - I # กำหนดขอบเขตของอาร์เรย์
  errR = df['R'][:70] - R # กำหนดขอบเขตของอาร์เรย์
  # print(errI, errR)

  errM = np.sum(errI**2+errR**2)/len(df['I'])**2
  if errM < errB:
    errB = errM
    beta_best = beta
    gamma_best = gamma
    print(beta_best, gamma_best, 1.0/gamma_best)
  beta  = np.random.uniform(0.0,2.0)
  gamma = 1.0/np.random.uniform(1,15)

#After optimizion
t = np.linspace(0, 150, 150)
ret = odeint(deriv, y0, t, args=(N, beta_best, gamma_best))
S, I, R = ret.T

# Plot the data on three separate curves for S(t), I(t) and R(t)
fig = plt.figure(facecolor='w')
ax = fig.add_subplot(111, facecolor='#dddddd', axisbelow=True)

ax.plot(t, S/1000, 'b', alpha=0.5, lw=2, label='Susceptible')
ax.plot(t, I/100, 'r', alpha=0.5, lw=2, label='Infected')

# ax.plot(t[0:70], df['I']/100, 'r+', alpha=0.5, lw=2, label='Infected')
ax.plot(t[:70], df['I'][:70]/100, 'r+', alpha=0.5, lw=2, label='Infected') # กำหนดขอบเขตของอาร์เรย์


ax.plot(t, R/100, 'g', alpha=0.5, lw=2, label='Recovered with immunity')

# ax.plot(t[0:70], df['R']/100, 'g*', alpha=0.5, lw=2, label='Recovered with immunity')
ax.plot(t[:70], df['R'][:70]/100, 'g*', alpha=0.5, lw=2, label='Recovered with immunity') # กำหนดขอบเขตของอาร์เรย์


ax.set_xlabel('Time /days')
ax.set_ylabel('Number (100s)')
ax.set_ylim(0,10)
ax.yaxis.set_tick_params(length=0)
ax.xaxis.set_tick_params(length=0)
legend = ax.legend()
legend.get_frame().set_alpha(0.5)
for spine in ('top', 'right', 'bottom', 'left'):
    ax.spines[spine].set_visible(False)
plt.show()
# Out:
# 1.0 0.14285714285714285 7.0
# 1.3889117061994443 0.07801483585598083 12.818074780623117
# 1.6890191108513595 0.0702346657595036 14.237983326128207
# 0.7595427614776333 0.07142219418230783 14.001250051874106
# 0.46213689755174947 0.19957127680100867 5.01074110477879
# 0.1411486212921116 0.34495483518685194 2.898930230846972
# 0.3567594305860242 0.47935746888843217 2.0861258348991
# 0.8109610492108634 0.8688316865743012 1.1509709135297306
# 0.10401879916205092 0.06786426032252114 14.735296535283156
# 0.1897340606494229 0.07619726225370343 13.123831098687496
# 0.185901470242813 0.06947817218370386 14.393009611075383
# 0.17632037461412886 0.07151740653334812 13.98260994732389
